# %%
import pandas as pd
import time

def bubblesort(list1):  
    has_swapped = True  
    total_iteration = 0  
    while(has_swapped):  
        has_swapped = False  
        for i in range(len(list1) - total_iteration - 1):  
            if list1[i] > list1[i+1]:  
                list1[i], list1[i+1] = list1[i+1], list1[i]  
                has_swapped = True  
        total_iteration += 1  

def insertionSort(arr):
    n=len(arr)
    for i in range(1, n):
        key = arr[i]
        j = i-1
        while j >=0 and key < arr[j] :
                arr[j+1] = arr[j]
                j -= 1
        arr[j+1] = key

# %%
# Measure execution time for Bubble Sort
algorithm_time = pd.DataFrame({'10^x':[],
                                'insertion':[],
                                'bubble':[]})

algorithm_time=pd.DataFrame(algorithm_time.groupby("10^x").sum())

def timing_algorithms(x:int):
    large_list = list(range(x, 0, -1))
    start_time = time.time()
    bubblesort(large_list)
    end_time = time.time()
    bubble_sort_time = end_time - start_time
    large_list = list(range(x, 0, -1))
    start_time = time.time()
    insertionSort(large_list)
    end_time = time.time()
    insertion_sort_time = end_time - start_time
    
#     se=pd.Series({'insertion': insertion_sort_time*1000, 'bubble': bubble_sort_time*1000}, name=x)
#     print(se.transpose())
    algorithm_time.loc[x] = [ insertion_sort_time*1000, bubble_sort_time*1000] 
    print(x)
    print("Bubble Sort execution time:", bubble_sort_time*1000)
    print("Insertion Sort execution time:", insertion_sort_time*1000)

# %%
fives=[5*10**(i+1) for i in range(4)]
fifi=[1.5*10**(i+1) for i in range(4)]
t10=[10**(i+1) for i in range(4)]
nums=[]
for i in(list(zip(t10,fifi,fives))):
    nums=nums+list(i)
del nums[-1]
nums=nums+[j*1000 for j in range(2,5)]+[x*1000 for x in range(6,10)]+[l*1000 for l in range(11,15)]
nums.sort()
print(nums)   
for val in nums: 
    val=int(val)
    timing_algorithms(val)
# Out:
# [10, 15.0, 50, 100, 150.0, 500, 1000, 1500.0, 2000, 3000, 4000, 5000, 6000, 7000, 8000, 9000, 10000, 11000, 12000, 13000, 14000, 15000.0]
# 10
# Bubble Sort execution time: 0.02193450927734375
# Insertion Sort execution time: 0.013589859008789062
# 15
# Bubble Sort execution time: 0.045299530029296875
# Insertion Sort execution time: 0.02574920654296875
# 50
# Bubble Sort execution time: 0.4038810729980469
# Insertion Sort execution time: 0.2932548522949219
# 100
# Bubble Sort execution time: 1.598358154296875
# Insertion Sort execution time: 1.0750293731689453
# 150
# Bubble Sort execution time: 3.681182861328125
# Insertion Sort execution time: 1.8608570098876953
# 500
# Bubble Sort execution time: 40.72117805480957
# Insertion Sort execution time: 17.867326736450195
# 1000
# Bubble Sort execution time: 164.23726081848145
# Insertion Sort execution time: 134.04130935668945
# 1500
# Bubble Sort execution time: 395.3986167907715
# Insertion Sort execution time: 176.32579803466797
# 2000
# Bubble Sort execution time: 554.0421009063721
# Insertion Sort execution time: 343.5182571411133
# 3000
# Bubble Sort execution time: 1233.2022190093994
# Insertion Sort execution time: 723.9272594451904
# 4000
# Bubble Sort execution time: 2161.05318069458
# Insertion Sort execution time: 1347.7628231048584
# 5000
# Bubble Sort execution time: 3407.789707183838
# Insertion Sort execution time: 2089.0567302703857
# 6000
# Bubble Sort execution time: 5071.015357971191
# Insertion Sort execution time: 2838.996648788452
# 7000
# Bubble Sort execution time: 7120.108842849731
# Insertion Sort execution time: 3833.8568210601807
# 8000
# Bubble Sort execution time: 8953.287839889526
# Insertion Sort execution time: 5091.077089309692
# 9000
# Bubble Sort execution time: 13567.707300186157
# Insertion Sort execution time: 7596.7512130737305
# 10000
# Bubble Sort execution time: 18566.067218780518
# Insertion Sort execution time: 9347.235441207886
# 11000
# Bubble Sort execution time: 18022.33839035034
# Insertion Sort execution time: 8639.35136795044
# 12000
# Bubble Sort execution time: 19229.6724319458
# Insertion Sort execution time: 12305.872440338135
# 13000
# Bubble Sort execution time: 22386.000156402588
# Insertion Sort execution time: 13579.69856262207
# 14000
# Bubble Sort execution time: 27858.436822891235
# Insertion Sort execution time: 17135.632514953613
# 15000
# Bubble Sort execution time: 29223.875284194946
# Insertion Sort execution time: 16021.861553192139

# %%
# algorithm_time=pd.DataFrame(algorithm_time.groupby("10^x").sum())
algorithm_time=algorithm_time.sort_index()
algorithm_time
# Out:
#           insertion        bubble
# 10^x
# 10         0.013590      0.021935
# 15         0.025749      0.045300
# 50         0.293255      0.403881
# 100        1.075029      1.598358
# 150        1.860857      3.681183
# 500       17.867327     40.721178
# 1000     134.041309    164.237261
# 1500     176.325798    395.398617
# 2000     343.518257    554.042101
# 3000     723.927259   1233.202219
# 4000    1347.762823   2161.053181
# 5000    2089.056730   3407.789707
# 6000    2838.996649   5071.015358
# 7000    3833.856821   7120.108843
# 8000    5091.077089   8953.287840
# 9000    7596.751213  13567.707300
# 10000   9347.235441  18566.067219
# 11000   8639.351368  18022.338390
# 12000  12305.872440  19229.672432
# 13000  13579.698563  22386.000156
# 14000  17135.632515  27858.436823
# 15000  16021.861553  29223.875284

# %%
algorithm_time.plot(figsize = (10, 7));

# %%
algorithm_time.iloc[:5].plot(figsize = (10, 7));
